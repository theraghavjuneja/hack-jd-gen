# %%
str2="""
\nYou are listing out your job on a platform.The details of jobs are given below\n    None.\n    \n    Please provide a much comprehensive and a detailed job description. Make sure to include the headers given below\n    -Designation of the Job\n    -Years of Experience Required\n    -Salary Offered\n    -Vacancies\n    -A Brief Overview of the Role(if not provided, think about the designation of the job and  generate a overview)\n    -Detailed Roles and Responsibilities(if not provided, think about the roles and responsibilities of this designation. For example,A frontend engineer can have following role. Collaborating with design and backend teams to generate user-friendly and  responsive interfaces  )\n    -Must-Have Skills(if not provided, think about skills of that job designation)\n    -Secondary Skills\n    -Benefits and Perks (if provided else think about Benfits a job role can have)\n    -Location (if provided, else write 'Location details will be shared with selected candidates')\n    -Certification Required (if provided, else say 'Certificates related to the There are a total of 5 vacancies of an AI Engineer in our company WhereUElevate(a next-gen startup which connects innovation with emerging talent). He must know concepts about langchain, large language models , deep learning with tensorflow or pytorch and some sort of mathematics and statistics. He should have an experience of atleast 2 years. If he has attained some certification of AI & ML then it is a plus point. He would be working in hybrid mode, sometimes in our office in greater noida and sometimes from home. The salary offered will be 5 lacs a year field are highly appreciated\n    \n    You are free to make more subheaders according to the input provided\n    \n    Additionally, ensure the generated content is SEO-friendly.   \n
"""

# %%
l1=str2.split(' ')
print(len(l1))
# Out:
# 334

# %%
for i in l1:
    print(i)
# Out:
# You
# are
# listing
# out
# your
# job
# on
# a
# platform.The
# details
# of
# jobs
# are
# given
# below
#
#
#
#
# None.
#
#
#
#
#
#
#
#
#
# Please
# provide
# a
# much
# comprehensive
# and
# a
# detailed
# job
# description.
# Make
# sure
# to
# include
# the
# headers
# given
# below
#
#
#
#
# -Designation
# of
# the
# Job
#
#
#
#
# -Years
# of
# Experience
# Required
#
#
#
#
# -Salary
# Offered
#
#
#
#
# -Vacancies
#
#
#
#
# -A
# Brief
# Overview
# of
# the
# Role(if
# not
# provided,
# think
# about
# the
# designation
# of
# the
# job
# and
#
# generate
# a
# overview)
#
#
#
#
# -Detailed
# Roles
# and
# Responsibilities(if
# not
# provided,
# think
# about
# the
# roles
# and
# responsibilities
# of
# this
# designation.
# For
# example,A
# frontend
# engineer
# can
# have
# following
# role.
# Collaborating
# with
# design
# and
# backend
# teams
# to
# generate
# user-friendly
# and
#
# responsive
# interfaces
#
# )
#
#
#
#
# -Must-Have
# Skills(if
# not
# provided,
# think
# about
# skills
# of
# that
# job
# designation)
#
#
#
#
# -Secondary
# Skills
#
#
#
#
# -Benefits
# and
# Perks
# (if
# provided
# else
# think
# about
# Benfits
# a
# job
# role
# can
# have)
#
#
#
#
# -Location
# (if
# provided,
# else
# write
# 'Location
# details
# will
# be
# shared
# with
# selected
# candidates')
#
#
#
#
# -Certification
# Required
# (if
# provided,
# else
# say
# 'Certificates
# related
# to
# the
# There
# are
# a
# total
# of
# 5
# vacancies
# of
# an
# AI
# Engineer
# in
# our
# company
# WhereUElevate(a
# next-gen
# startup
# which
# connects
# innovation
# with
# emerging
# talent).
# He
# must
# know
# concepts
# about
# langchain,
# large
# language
# models
# ,
# deep
# learning
# with
# tensorflow
# or
# pytorch
# and
# some
# sort
# of
# mathematics
# and
# statistics.
# He
# should
# have
# an
# experience
# of
# atleast
# 2
# years.
# If
# he
# has
# attained
# some
# certification
# of
# AI
# &
# ML
# then
# it
# is
# a
# plus
# point.
# He
# would
# be
# working
# in
# hybrid
# mode,
# sometimes
# in
# our
# office
# in
# greater
# noida
# and
# sometimes
# from
# home.
# The
# salary
# offered
# will
# be
# 5
# lacs
# a
# year
# field
# are
# highly
# appreciated
#
#
#
#
#
#
#
#
#
# You
# are
# free
# to
# make
# more
# subheaders
# according
# to
# the
# input
# provided
#
#
#
#
#
#
#
#
#
# Additionally,
# ensure
# the
# generated
# content
# is
# SEO-friendly.
